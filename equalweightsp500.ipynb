# %% [markdown]
# ### Equal-Weight-S&P500 Index Fund

# %% [markdown]
# #### Introduction and Library Imports
#
# The S&P500 is the world's most popular stock market index. The largest fund that is benchmarket to this index is SPDR S&P500 ETF Trust. It has more than USD$250 billion of assets under management.
#
# The goal of this section of the course is to create a Python script that will accept the value of the portfolio and tell you how many shares of each S&P 500 constituent you should purchase to get an equal-weight version of the index fund.

# %%
# Import libraries
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
import warnings

warnings.filterwarnings("ignore")

# %%
# Webscrapping Stock Analysis table to get the SP500 data
page = requests.get("https://stockanalysis.com/list/sp-500-stocks")
soup = BeautifulSoup(page.text, 'html.parser') 
table = soup.find_all('table')

# %%
# Convert html table to dataframe
wiki = pd.read_html(str(table))
wiki = pd.concat(wiki)
wiki.head(40)
# Out:
#     No. Symbol                                 Company Name Market Cap  \
# 0     1   AAPL                                   Apple Inc.  3,143.82B
# 1     2   MSFT                        Microsoft Corporation  2,913.01B
# 2     3   NVDA                           NVIDIA Corporation  2,708.64B
# 3     4   AMZN                             Amazon.com, Inc.  2,005.63B
# 4     5   GOOG                                Alphabet Inc.  1,975.70B
# 5     6  GOOGL                                Alphabet Inc.  1,968.62B
# 6     7   META                         Meta Platforms, Inc.  1,381.56B
# 7     8  BRK.B                      Berkshire Hathaway Inc.  1,145.09B
# 8     9   TSLA                                  Tesla, Inc.    917.81B
# 9    10   AVGO                                Broadcom Inc.    904.23B
# 10   11    LLY                        Eli Lilly and Company    794.31B
# 11   12    WMT                                 Walmart Inc.    762.32B
# 12   13    JPM                         JPMorgan Chase & Co.    676.85B
# 13   14      V                                    Visa Inc.    654.78B
# 14   15     MA                      Mastercard Incorporated    487.50B
# 15   16    XOM                      Exxon Mobil Corporation    469.60B
# 16   17   NFLX                                Netflix, Inc.    468.78B
# 17   18   COST                 Costco Wholesale Corporation    433.55B
# 18   19   ORCL                           Oracle Corporation    388.36B
# 19   20    UNH              UnitedHealth Group Incorporated    381.06B
# 20   21     PG                 The Procter & Gamble Company    377.52B
# 21   22    JNJ                            Johnson & Johnson    371.93B
# 22   23     HD                         The Home Depot, Inc.    355.41B
# 23   24   ABBV                                  AbbVie Inc.    329.14B
# 24   25     KO                        The Coca-Cola Company    309.47B
# 25   26    BAC                  Bank of America Corporation    300.06B
# 26   27     PM             Philip Morris International Inc.    264.98B
# 27   28   PLTR                   Palantir Technologies Inc.    264.51B
# 28   29   TMUS                            T-Mobile US, Inc.    264.30B
# 29   30    CRM                             Salesforce, Inc.    257.40B
# 30   31    CVX                          Chevron Corporation    244.25B
# 31   32    WFC                        Wells Fargo & Company    227.68B
# 32   33    MCD                       McDonald's Corporation    226.49B
# 33   34   CSCO                          Cisco Systems, Inc.    225.61B
# 34   35    ABT                          Abbott Laboratories    223.47B
# 35   36    LIN                                    Linde plc    212.05B
# 36   37     GE                     General Electric Company    211.60B
# 37   38    IBM  International Business Machines Corporation    211.35B
# 38   39    MRK                            Merck & Co., Inc.    208.21B
# 39   40    NOW                             ServiceNow, Inc.    195.65B
#
#     Stock Price % Change  Revenue
# 0        209.28    0.44%  395.76B
# 1        391.85    1.17%  261.80B
# 2        111.01    4.30%  130.50B
# 3        188.99    1.31%  637.96B
# 4        163.85    1.47%  359.71B
# 5        161.96    1.68%  359.71B
# 6        547.27    2.65%  164.50B
# 7        531.00   -0.12%  371.43B
# 8        284.95    9.80%   95.72B
# 9        192.31    2.21%   54.53B
# 10       884.54    2.89%   45.04B
# 11        95.09   -0.78%  680.99B
# 12       243.55   -0.45%  168.73B
# 13       335.17   -0.16%   36.80B
# 14       533.48   -0.37%   28.17B
# 15       108.57   -0.06%  340.57B
# 16      1101.53    0.42%   40.17B
# 17       977.16    0.17%  264.09B
# 18       138.43    0.67%   55.78B
# 19       418.64   -1.32%  410.06B
# 20       161.02    0.93%   83.93B
# 21       154.58   -0.23%   89.33B
# 22       357.58   -0.57%  159.51B
# 23       186.06    3.15%   57.37B
# 24        71.91   -0.84%   47.06B
# 25        39.69    0.28%   97.45B
# 26       170.24    0.10%   38.39B
# 27       112.78    4.64%    2.87B
# 28       232.77  -11.22%   82.69B
# 29       267.85    1.19%   37.90B
# 30       138.73   -0.24%  195.57B
# 31        69.73    0.24%   77.25B
# 32       316.74    0.16%   25.92B
# 33        56.71    0.75%   54.18B
# 34       128.85   -0.41%   42.34B
# 35       448.40   -0.25%   33.01B
# 36       198.43    0.52%   39.68B
# 37       232.41    1.34%   62.83B
# 38        82.74    3.63%   63.92B
# 39       945.26    0.71%   11.47B

# %%
final_dataframe = wiki[['Symbol','Stock Price','Market Cap']]
final_dataframe['Number of Shares to Buy'] = 0
final_dataframe
# Out:
#     Symbol  Stock Price Market Cap  Number of Shares to Buy
# 0     AAPL       209.28  3,143.82B                        0
# 1     MSFT       391.85  2,913.01B                        0
# 2     NVDA       111.01  2,708.64B                        0
# 3     AMZN       188.99  2,005.63B                        0
# 4     GOOG       163.85  1,975.70B                        0
# ..     ...          ...        ...                      ...
# 498    IVZ        13.93      6.24B                        0
# 499   ENPH        46.83      6.14B                        0
# 500    CZR        28.44      6.03B                        0
# 501    APA        16.35      5.91B                        0
# 502    CRL       114.66      5.63B                        0
#
# [503 rows x 4 columns]

# %%
portfolio_size = input("Enter the portfolio size: ")

try:
    val = float(portfolio_size)
except ValueError:
    print("Invalid input. Please enter a numeric value.")

# %%
# Calculate the number of shares to buy for each stock
position_size = val / len(final_dataframe)
final_dataframe['Number of Shares to Buy'] = (position_size / final_dataframe['Stock Price']).apply(np.floor)
final_dataframe['Number of Shares to Buy'] = final_dataframe['Number of Shares to Buy'].astype(int)
final_dataframe
# Out:
#     Symbol  Stock Price Market Cap  Number of Shares to Buy
# 0     AAPL       209.28  3,143.82B                        0
# 1     MSFT       391.85  2,913.01B                        0
# 2     NVDA       111.01  2,708.64B                        1
# 3     AMZN       188.99  2,005.63B                        1
# 4     GOOG       163.85  1,975.70B                        1
# ..     ...          ...        ...                      ...
# 498    IVZ        13.93      6.24B                       14
# 499   ENPH        46.83      6.14B                        4
# 500    CZR        28.44      6.03B                        6
# 501    APA        16.35      5.91B                       12
# 502    CRL       114.66      5.63B                        1
#
# [503 rows x 4 columns]
